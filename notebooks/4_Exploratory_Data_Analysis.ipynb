# %% [markdown]
# ## Description

# %% [markdown]
# This is the fourth of five notebooks documenting a pipelined approach to out-of-core computation using Dask and a Stochastic Gradient Descent classifier available in Scikit-learn. Specifically, it steps through several EDA approaches to get us better acquanted with the data.

# %% [markdown]
# ## Libraries

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from pandas.plotting import scatter_matrix

# %% [markdown]
# ## Versions

# %%
items = [("Numpy", np), ("Pandas", pd), ("Matplotlib", matplotlib), ("Seaborn", sns)]
for item in items:
    print(item[0] + " version: " + str(item[1].__version__))
# Out:
# Numpy version: 1.13.0
# Pandas version: 0.20.1
# Matplotlib version: 2.0.2
# Seaborn version: 0.7.1

# %% [markdown]
# ## Get Data

# %%
path = '/Users/davidziganto/data/'
X = pd.read_hdf(path + 'raw_HIGGS_training_data.h5', key='/a')

# %% [markdown]
# #### Dataframe Metadata

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8800000 entries, 0 to 8799999
# Data columns (total 29 columns):
# lepton_pT                   float64
# lepton_eta                  float64
# lepton_phi                  float64
# missing_energy_magnitude    float64
# missing_energy_phi          float64
# jet_1_pt                    float64
# jet_1_eta                   float64
# jet_1_phi                   float64
# jet_1_b_tag                 float64
# jet_2_pt                    float64
# jet_2_eta                   float64
# jet_2_phi                   float64
# jet_2_b_tag                 float64
# jet_3_pt                    float64
# jet_3_eta                   float64
# jet_3_phi                   float64
# jet_3_b_tag                 float64
# jet_4_pt                    float64
# jet_4_eta                   float64
# jet_4_phi                   float64
# jet_4_b_tag                 float64
# m_jj                        float64
# m_jjj                       float64
# ...

# %% [markdown]
# #### Dataframe Stats

# %%
X.describe()
# Out:
#           lepton_pT    lepton_eta    lepton_phi  missing_energy_magnitude  \
# count  8.800000e+06  8.800000e+06  8.800000e+06              8.800000e+06
# mean   9.913941e-01  1.812409e-05  1.202841e-04              9.984791e-01
# std    5.652263e-01  1.008586e+00  1.006298e+00              6.000232e-01
# min    2.746966e-01 -2.434976e+00 -1.742508e+00              2.370088e-04
# 25%    5.907533e-01 -7.383225e-01 -8.713760e-01              5.767606e-01
# 50%    8.533714e-01 -5.415563e-05  3.137559e-04              8.915848e-01
# 75%    1.236226e+00  7.382142e-01  8.715489e-01              1.292821e+00
# max    1.209891e+01  2.434868e+00  1.743236e+00              1.539682e+01
#
#        missing_energy_phi      jet_1_pt     jet_1_eta     jet_1_phi  \
# count        8.800000e+06  8.800000e+06  8.800000e+06  8.800000e+06
# mean         5.835181e-06  9.908479e-01  2.606389e-04 -3.532179e-05
# std          1.006288e+00  4.747621e-01  1.009313e+00  1.005880e+00
# ...

# %% [markdown]
# #### Correlation Matrix

# %%
X.corr()
# Out:
#                           lepton_pT  lepton_eta  lepton_phi  \
# lepton_pT                  1.000000   -0.000346   -0.000083
# lepton_eta                -0.000346    1.000000    0.000155
# lepton_phi                -0.000083    0.000155    1.000000
# missing_energy_magnitude  -0.139666   -0.000480   -0.000065
# missing_energy_phi         0.000289   -0.000090   -0.044419
# jet_1_pt                   0.165607   -0.000388    0.000037
# jet_1_eta                 -0.000162    0.264802    0.000848
# jet_1_phi                 -0.000395   -0.000487   -0.167835
# jet_1_b_tag               -0.006362    0.000224   -0.000449
# jet_2_pt                   0.004597    0.000275   -0.000068
# jet_2_eta                  0.000036    0.264543    0.000284
# jet_2_phi                 -0.000093   -0.000428   -0.093755
# jet_2_b_tag               -0.005769   -0.000097    0.000246
# jet_3_pt                  -0.011102    0.000658    0.000032
# jet_3_eta                  0.000351    0.226224    0.000944
# ...

# %% [markdown]
# #### Check for Nulls

# %%
X.isnull().sum()
# Out:
# lepton_pT                   0
# lepton_eta                  0
# lepton_phi                  0
# missing_energy_magnitude    0
# missing_energy_phi          0
# jet_1_pt                    0
# jet_1_eta                   0
# jet_1_phi                   0
# jet_1_b_tag                 0
# jet_2_pt                    0
# jet_2_eta                   0
# jet_2_phi                   0
# jet_2_b_tag                 0
# jet_3_pt                    0
# jet_3_eta                   0
# jet_3_phi                   0
# jet_3_b_tag                 0
# jet_4_pt                    0
# jet_4_eta                   0
# jet_4_phi                   0
# jet_4_b_tag                 0
# m_jj                        0
# m_jjj                       0
# m_lv                        0
# m_jlv                       0
# m_bb                        0
# m_wbb                       0
# m_wwbb                      0
# label                       0
# dtype: int64

# %% [markdown]
# #### Check Class Balance

# %%
round(X.label.mean(), 3)
# Out:
# 0.53

# %% [markdown]
# #### Boxplot

# %%
sns.boxplot(data=X, orient='h');

# %% [markdown]
# ## Feature Importances

# %%
from sklearn.ensemble import RandomForestClassifier

y = X.pop('label')

rf = RandomForestClassifier(n_estimators=25, 
                            criterion='gini', 
                            max_depth=None, 
                            min_samples_split=2, 
                            min_samples_leaf=1, 
                            min_weight_fraction_leaf=0.0, 
                            max_features='auto', 
                            max_leaf_nodes=None, 
                            min_impurity_split=1e-07, 
                            bootstrap=True, 
                            oob_score=False, 
                            n_jobs=-1, 
                            random_state=123, 
                            verbose=0, 
                            warm_start=False, 
                            class_weight="balanced_subsample")

rf.fit(X, y)

features = X.columns
importances = rf.feature_importances_
indices = np.argsort(importances)

plt.figure(1)
plt.title('Feature Importances')
plt.barh(range(len(indices[-10:])), importances[indices[-10:]], color='b', align='center')
plt.yticks(range(len(indices[-10:])), features[indices])
plt.xlabel('Relative Importance');
